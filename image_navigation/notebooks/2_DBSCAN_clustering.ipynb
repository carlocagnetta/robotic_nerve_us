# %% [markdown]
# # DBSCAN Clustering search

# %%
# import
import sys
sys.path.append('../')

import logging
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

from visualization_utils import show_clusters
from tissue_clustering import Tissues
from loss import loss_fct

# Set up the logger
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# %%
# Load the image data
mri_1_label = sitk.ReadImage('..\MRI\Labels\labels_00001.nii')
mri_1_label_data = sitk.GetArrayFromImage(mri_1_label)
mri_1_label_data.shape
# Out:
# (61, 864, 606)

# %%
tissues = { "bones": 20,
            "tendins": 2,
            "ulnar": 3,}

# %%
tissuesClass = Tissues(tissues_dict=tissues)
tissuesClass.get_tissues()
# Out:
# {'bones': 20, 'tendins': 2, 'ulnar': 3}

# %% [markdown]
# DBSCAN might be a better clustering technique that offers more flexibility. In this script we are going to analyze this and similar clustering algorithms and their performance on our loss function

# %%
from sklearn.cluster import DBSCAN

def find_DBSCAN_clusters(label: int, slice: np.array, eps: float, min_samples: int) -> None:
        
    # binary filter for the label
    binary_mask = (slice == label)

    # Check if there are tissues with given label
    if np.all(binary_mask == False):
        print("No tissues to cluster. Please set values using set_values method.")
        return []
    
    # find label positions, upon which clustering wil be defined
    label_positions = np.array(list(zip(*np.where(binary_mask))))

    # define clusterer
    clusterer = DBSCAN(eps=eps, min_samples=min_samples)

    # find cluster prediction
    labels = clusterer.fit_predict(label_positions)
    n_labels = len(np.unique(labels)) - 1 # noise cluster has label -1, we dont take it into account
    print(f"Found {n_labels} clusters")

    # Extract clusters and their centers
    cluster_data = []

    for label in range(n_labels):
        label_to_pos_array = label_positions[labels == label] # get positions of each cluster
        cluster_centers = np.mean(label_to_pos_array, axis=0) # mean of each column
        # Save both the cluster and center under the same key
        cluster_data.append({'cluster': label_to_pos_array,
                            'center': cluster_centers})

    return cluster_data

# %%
def DBSCAN_cluster_iter(tissues: dict, slice: np.ndarray, eps: float, min_samples: int) -> dict:
    # store clsuters of tissues in a dict
    tissues_clusters = {}
    
    for tissue in tissues:
        print(f"Finding {tissue} clusters, with value {tissues[tissue]}:")
        # find clusters for each tissue
        tissues_clusters[tissue] = (find_DBSCAN_clusters(tissues[tissue], slice, eps, min_samples))

        # print the identified clusters and their centers
        for index, data in enumerate(tissues_clusters[tissue]):
            print(f"Center of {tissue} cluster {index}: {data['center']}")
    print("---------------------------------------\n")     
    return tissues_clusters

# %%
clusters_680 = {}
clusters_680['bones'] = find_DBSCAN_clusters(tissues['bones'], mri_1_label_data[:, 680, :], eps=2.5, min_samples=20)
clusters_680['tendins'] = find_DBSCAN_clusters(tissues['tendins'], mri_1_label_data[:, 680, :], eps=2.5, min_samples=20)
clusters_680['ulnar'] = find_DBSCAN_clusters(tissues['ulnar'], mri_1_label_data[:, 680, :], eps=2., min_samples=12)

show_clusters(clusters_680, mri_1_label_data[:, 680, :])

plt.show()
# Out:
# Found 7 clusters
# Found 2 clusters
# Found 1 clusters

# %%
sweep_loss = []

for i in range(mri_1_label_data.shape[1]):
    clusters = {}
    clusters['bones'] = find_DBSCAN_clusters(tissues['bones'], mri_1_label_data[:, i, :], eps=4.1, min_samples=46)
    clusters['tendins'] = find_DBSCAN_clusters(tissues['tendins'], mri_1_label_data[:, i, :], eps=4.1, min_samples=46)
    clusters['ulnar'] = find_DBSCAN_clusters(tissues['ulnar'], mri_1_label_data[:, i, :], eps=2.5, min_samples=18)

    loss = loss_fct(clusters)
    print(f"Loss for slice {i}: {loss}")    
    sweep_loss.append(loss)

# Plot the loss results over the length of the data
plt.plot(range(len(sweep_loss)), sweep_loss, marker='o')

# Add labels and title
plt.xlabel('Data Length')
plt.ylabel('Loss')
plt.title('Loss Function Results')

# Show the plot
plt.show()
# Out:
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 0: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 1: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 2: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 3: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 4: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 5: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 6: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 7: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 8: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 9: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 10: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 11: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 12: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 13: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 14: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 15: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 16: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 17: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 18: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 19: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 20: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 21: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 22: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 23: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 24: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 25: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 26: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 27: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 28: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 29: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 30: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 31: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 32: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 33: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 34: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 35: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 36: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 37: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 38: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 39: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 40: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 41: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 42: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 43: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 44: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 45: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 46: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 47: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 48: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 49: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 50: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 51: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 52: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 53: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 54: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 55: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 56: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 57: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 58: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 59: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 60: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 61: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 62: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 63: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 64: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 65: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 66: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 67: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 68: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 69: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 70: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 71: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 72: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 73: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 74: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 75: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 76: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 77: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 78: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 79: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 80: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 81: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 82: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 83: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 84: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 85: 1.0
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 86: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 87: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 88: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 89: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 90: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 91: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 92: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 93: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 94: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 95: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 96: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 97: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 98: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 99: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 100: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 101: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 102: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 103: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 104: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 105: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 106: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 107: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 108: 1.0
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ...
#
# Loss for slice 815: 0.8222222222222222
# Found 1 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 8
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8222222222222222
# ####################################################
#
# Loss for slice 816: 0.8222222222222222
# Found 1 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 8
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8222222222222222
# ####################################################
#
# Loss for slice 817: 0.8222222222222222
# Found 1 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 8
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8222222222222222
# ####################################################
#
# Loss for slice 818: 0.8222222222222222
# Found 1 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 8
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8222222222222222
# ####################################################
#
# Loss for slice 819: 0.8222222222222222
# Found 1 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 8
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8222222222222222
# ####################################################
#
# Loss for slice 820: 0.8222222222222222
# Found 2 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 7
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.7888888888888889
# ####################################################
#
# Loss for slice 821: 0.7888888888888889
# Found 2 clusters
# Found 0 clusters
# Found 1 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 7
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.7888888888888889
# ####################################################
#
# Loss for slice 822: 0.7888888888888889
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 823: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 824: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 825: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 826: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 827: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 828: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 829: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 830: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 831: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 832: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 833: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 834: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 835: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 836: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 837: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 838: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 839: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 840: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 841: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 842: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 843: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 844: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 845: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 846: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 847: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 848: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 849: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 850: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 851: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 852: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 853: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 854: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 855: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 856: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 857: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 858: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 859: 0.8555555555555554
# Found 1 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No tendins found
# Landmark loss: 9
# Missing landmark loss: 2
# Location loss: 1
# Total loss: 0.8555555555555554
# ####################################################
#
# Loss for slice 860: 0.8555555555555554
# Found 0 clusters
# Found 0 clusters
# Found 0 clusters
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 861: 1.0
# Found 0 clusters
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 862: 1.0
# Found 0 clusters
# Found 0 clusters
# No tissues to cluster. Please set values using set_values method.
# ####################################################
# Calculating loss function:
# No bones found
# Landmark loss: 10
# Missing landmark loss: 3
# Location loss: 1
# Total loss: 1.0
# ####################################################
#
# Loss for slice 863: 1.0

# %%
# Find indices where the loss is equal to 0
zero_loss_indices = np.where(np.array(sweep_loss) == 0)[0]
print(f"{len(zero_loss_indices)} indices return a zero loss: ", zero_loss_indices)

# Create a subplot for each image with 0 loss
fig, axes = plt.subplots(2, 4, figsize=(21, 7))

axes = axes.flatten()
for i, idx in enumerate(zero_loss_indices):
    # Plot the image
    axes[i].imshow(mri_1_label_data[:, idx, :], aspect=6)
    axes[i].set_title(f'Index: {idx}, Loss: {sweep_loss[idx]:.2f}')
    axes[i].axis('off')

plt.show()
# Out:
# 8 indices return a zero loss:  [669 670 671 672 673 674 675 676]

# %%
from sklearn.cluster import HDBSCAN

def find_HDBSCAN_clusters(label: int, slice: np.array, 
                          min_cluster_size: int = 5, min_samples: int = None, 
                          eps: float = 0.0, max_cluster_size: int = None) -> None:
        
    # binary filter for the label
    binary_mask = (slice == label)

    # Check if there are tissues with given label
    if np.all(binary_mask == False):
        print("No tissues to cluster. Please set values using set_values method.")
        return []
    
    # find label positions, upon which clustering wil be defined
    label_positions = np.array(list(zip(*np.where(binary_mask))))

    # define clusterer
    clusterer = HDBSCAN(min_cluster_size=min_cluster_size, min_samples=min_samples,
                        cluster_selection_epsilon=eps, max_cluster_size=max_cluster_size, allow_single_cluster=True)

    # find cluster prediction
    labels = clusterer.fit_predict(label_positions)
    n_labels = len(np.unique(labels)) - 1 # noise cluster has label -1, we dont take it into account
    print(f"Found {n_labels} clusters")

    # Extract clusters and their centers
    cluster_data = []

    for label in range(n_labels):
        label_to_pos_array = label_positions[labels == label] # get positions of each cluster
        cluster_centers = np.mean(label_to_pos_array, axis=0) # mean of each column
        # Save both the cluster and center under the same key
        cluster_data.append({'cluster': label_to_pos_array,
                            'center': cluster_centers})

    return cluster_data

# %%
HDB_cluster = {}
HDB_cluster['bones'] = find_HDBSCAN_clusters(tissues['bones'], mri_1_label_data[:, 673, :], 
                                             min_cluster_size=50, max_cluster_size=350, eps=2.5, min_samples=16)

HDB_cluster['tendins'] = find_HDBSCAN_clusters(tissues['tendins'], mri_1_label_data[:, 673, :], 
                                             min_cluster_size=20, max_cluster_size=200)

HDB_cluster['ulnar'] = find_HDBSCAN_clusters(tissues['ulnar'], mri_1_label_data[:, 673, :], 
                                             min_cluster_size=6, max_cluster_size=30)
show_clusters(HDB_cluster, mri_1_label_data[:, 673, :])
# Out:
# Found 4 clusters
# Found 1 clusters
# Found 1 clusters

# %%
# print the size of each cluster
for tissue in HDB_cluster:
    for index, data in enumerate(HDB_cluster[tissue]):
        print(f"Size of {tissue} cluster {index}: {len(data['cluster'])}")
# Out:
# Size of bones cluster 0: 193
# Size of bones cluster 1: 491
# Size of bones cluster 2: 188
# Size of bones cluster 3: 345
# Size of tendins cluster 0: 106
# Size of ulnar cluster 0: 22
